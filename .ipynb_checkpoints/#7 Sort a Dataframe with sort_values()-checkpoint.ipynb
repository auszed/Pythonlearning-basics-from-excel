# %% [markdown]
# # data import

# %%
# import pandas
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('sales.csv')
df_exams.head()
# Out:
# C:\Users\hanns\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     order_id  order_date    status   item_id                  sku  \
# 0  100354678  2020-10-01  received  574772.0   oasis_Oasis-064-36
# 1  100354678  2020-10-01  received  574774.0      Fantastic_FT-48
# 2  100354680  2020-10-01  complete  574777.0      mdeal_DMC-610-8
# 3  100354680  2020-10-01  complete  574779.0   oasis_Oasis-061-36
# 4  100367357  2020-11-13  received  595185.0  MEFNAR59C38B6CA08CD
#
#    qty_ordered  price   value  discount_amount   total  ...          SSN  \
# 0         21.0   89.9  1798.0              0.0  1798.0  ...  627-31-5251
# 1         11.0   19.0   190.0              0.0   190.0  ...  627-31-5251
# 2          9.0  149.9  1199.2              0.0  1199.2  ...  627-31-5251
# ...

# %%
df_exams.dtypes
# Out:
# order_id             object
# order_date           object
# status               object
# item_id             float64
# sku                  object
# qty_ordered         float64
# price               float64
# value               float64
# discount_amount     float64
# total               float64
# category             object
# payment_method       object
# bi_st                object
# cust_id             float64
# year                  int64
# month                object
# ref_num               int64
# Name Prefix          object
# First Name           object
# Middle Initial       object
# Last Name            object
# Gender               object
# age                 float64
# full_name            object
# E Mail               object
# Customer Since       object
# SSN                  object
# Phone No.            object
# Place Name           object
# County               object
# City                 object
# State                object
# Zip                   int64
# ...

# %% [markdown]
# # Sort a Dataframe # data

# %%
# sort by one column
df_exams.sort_values('qty_ordered').head()
# Out:
#          order_id  order_date    status   item_id                  sku  \
# 32942   100449587  2021-03-05  canceled  738084.0  MATHUA5A0C4EEFA7A5B
# 261399  100530668  2021-06-19  received  851582.0  APPDAW5A0C6FF001270
# 103869  100410634  2020-12-26  complete  670511.0  APPORI5A05B1DAD0085
# 261401  100530687  2021-06-19  received  851619.0  MATHUA5AE2C69026776
# 212538  100474445  2021-04-11  canceled  776952.0  ENTECO5A61FF549BC99
#
#         qty_ordered   price  value  discount_amount  total  ...          SSN  \
# 32942           1.0  1366.7    0.0              0.0    0.0  ...  021-94-5668
# 261399          1.0   926.4    0.0              0.0    0.0  ...  374-37-7379
# 103869          1.0  4157.9    0.0              0.0    0.0  ...  222-11-8424
# 261401          1.0  2437.5    0.0              0.0    0.0  ...  374-37-7379
# 212538          1.0  2927.1    0.0              0.0    0.0  ...  157-23-9961
#
# ...

# %%
# sort descending by one column
df_exams.sort_values('qty_ordered', ascending=False).head()
# Out:
#          order_id  order_date          status   item_id                  sku  \
# 65965   100535708  2021-06-29  order_refunded  859845.0  OTHOTH5A0945D0A72F4
# 65967   100535714  2021-06-29  order_refunded  859851.0  OTHOTH5A0945D0A72F4
# 257824  100526219  2021-06-13  order_refunded  845510.0  OTHOTH5A0945D0A72F4
# 263208  100533890  2021-06-25  order_refunded  856247.0  OTHOTH5A0945D0A72F4
# 65966   100535711  2021-06-29  order_refunded  859848.0  OTHOTH5A0945D0A72F4
#
#         qty_ordered  price  value  discount_amount  total  ...          SSN  \
# 65965         501.0    0.2  100.0              0.0  100.0  ...  680-31-0296
# 65967         501.0    0.2  100.0              0.0  100.0  ...  680-31-0296
# 257824        501.0    0.2  100.0              0.0  100.0  ...  288-15-4651
# 263208        501.0    0.2  100.0              0.0  100.0  ...  544-81-5780
# 65966         501.0    0.2  100.0              0.0  100.0  ...  680-31-0296
#
# ...

# %% [markdown]
# ### sort by multiple columns [ ]

# %% [markdown]
# remember to add [ ] because we are using multiple values

# %%
# sort descending by multiple columns
df_exams.sort_values(['order_date', 'qty_ordered'], ascending=False).head()
# Out:
#          order_id  order_date   status   item_id                  sku  \
# 285229  100562368  2021-09-30      cod  905183.0  SADBWH5B74016CC02D8
# 132953  100562323  2021-09-30  pending  905125.0  APPOSA5ACDCB6C15A68
# 132954  100562323  2021-09-30  pending  905126.0  APPOSA5ACDC3029F2C4
# 5111    100562382  2021-09-30  pending  905199.0  MATINF59BAB39FDBEF1
# 87707   100562359  2021-09-30     paid  905170.0  BAGPAR5AE95DB431B61
#
#         qty_ordered  price   value  discount_amount   total  ...          SSN  \
# 285229         11.0   30.0   300.0              0.0   300.0  ...  303-37-8555
# 132953          6.0    3.1    15.5              0.0    15.5  ...  727-10-1213
# 132954          6.0    2.8    14.0              0.0    14.0  ...  727-10-1213
# 5111            3.0  676.0  1352.0              0.0  1352.0  ...  422-67-7179
# 87707           3.0   52.0   104.0              0.0   104.0  ...  250-99-1593
#
# ...

# %%
df_exams.head(3)
# Out:
#     order_id  order_date    status   item_id                 sku  qty_ordered  \
# 0  100354678  2020-10-01  received  574772.0  oasis_Oasis-064-36         21.0
# 1  100354678  2020-10-01  received  574774.0     Fantastic_FT-48         11.0
# 2  100354680  2020-10-01  complete  574777.0     mdeal_DMC-610-8          9.0
#
#    price   value  discount_amount   total  ...          SSN    Phone No.   \
# 0   89.9  1798.0              0.0  1798.0  ...  627-31-5251  405-959-1129
# 1   19.0   190.0              0.0   190.0  ...  627-31-5251  405-959-1129
# 2  149.9  1199.2              0.0  1199.2  ...  627-31-5251  405-959-1129
#
#   Place Name  County    City State    Zip Region User Name Discount_Percent
# 0     Vinson  Harmon  Vinson    OK  73571  South   jwtitus              0.0
# 1     Vinson  Harmon  Vinson    OK  73571  South   jwtitus              0.0
# 2     Vinson  Harmon  Vinson    OK  73571  South   jwtitus              0.0
#
# [3 rows x 36 columns]

# %% [markdown]
# ### inplace allows to change the metrics in the whole data

# %% [markdown]
# as you can see above this was the value before the update, but when we used inplace the whole dataframe its update

# %%
# sort descending by multiple columns and update dataframe
df_exams.sort_values(['order_date', 'qty_ordered'], ascending=False, inplace=True)

# %%
df_exams.head(3)
# Out:
#          order_id  order_date   status   item_id                  sku  \
# 285229  100562368  2021-09-30      cod  905183.0  SADBWH5B74016CC02D8
# 132953  100562323  2021-09-30  pending  905125.0  APPOSA5ACDCB6C15A68
# 132954  100562323  2021-09-30  pending  905126.0  APPOSA5ACDC3029F2C4
#
#         qty_ordered  price  value  discount_amount  total  ...          SSN  \
# 285229         11.0   30.0  300.0              0.0  300.0  ...  303-37-8555
# 132953          6.0    3.1   15.5              0.0   15.5  ...  727-10-1213
# 132954          6.0    2.8   14.0              0.0   14.0  ...  727-10-1213
#
#           Phone No.  Place Name     County      City State    Zip Region  \
# 285229  304-401-5727    Parsons     Tucker   Parsons    WV  26287  South
# 132953  803-241-8251   Columbia  Lexington  Columbia    SC  29228  South
# 132954  803-241-8251   Columbia  Lexington  Columbia    SC  29228  South
#
#         User Name Discount_Percent
# 285229  pgmccurdy              0.0
# ...

# %% [markdown]
# # Sort a Dataframe string or text data

# %%
# sort descending with a key function
df_exams.sort_values(['County'], ascending=True, key=lambda a:a.str.lower()).head(3)
# Out:
#          order_id  order_date    status   item_id                  sku  \
# 279233  100561093  2021-09-21  received  902822.0  APPPHI5B37BAC0584C2
# 279232  100551127  2021-08-18  canceled  886131.0  COMTAR5B3C969B6EAE1
# 47640   100365554  2020-11-12  canceled  592602.0  BAGJUN59C10BDD0596A
#
#         qty_ordered  price  value  discount_amount  total  ...          SSN  \
# 279233          2.0  655.0  655.0              0.0  655.0  ...  108-98-3046
# 279232          2.0  338.6  338.6              0.0  338.6  ...  108-98-3046
# 47640           5.0  238.5  954.0            381.6  572.4  ...  090-02-7506
#
#           Phone No.  Place Name     County     City State    Zip Region  \
# 279233  270-594-8975      Aaron      Aaron    Aaron    KY  42601  South
# 279232  270-594-8975      Aaron      Aaron    Aaron    KY  42601  South
# 47640   803-907-3929    Donalds  Abbeville  Donalds    SC  29638  South
#
#           User Name Discount_Percent
# 279233    nktoliver              0.0
# ...

# %%
df_exams.sort_values(['County'], ascending=True).head(3)
# Out:
#          order_id  order_date    status   item_id                  sku  \
# 279233  100561093  2021-09-21  received  902822.0  APPPHI5B37BAC0584C2
# 279232  100551127  2021-08-18  canceled  886131.0  COMTAR5B3C969B6EAE1
# 47640   100365554  2020-11-12  canceled  592602.0  BAGJUN59C10BDD0596A
#
#         qty_ordered  price  value  discount_amount  total  ...          SSN  \
# 279233          2.0  655.0  655.0              0.0  655.0  ...  108-98-3046
# 279232          2.0  338.6  338.6              0.0  338.6  ...  108-98-3046
# 47640           5.0  238.5  954.0            381.6  572.4  ...  090-02-7506
#
#           Phone No.  Place Name     County     City State    Zip Region  \
# 279233  270-594-8975      Aaron      Aaron    Aaron    KY  42601  South
# 279232  270-594-8975      Aaron      Aaron    Aaron    KY  42601  South
# 47640   803-907-3929    Donalds  Abbeville  Donalds    SC  29638  South
#
#           User Name Discount_Percent
# 279233    nktoliver              0.0
# ...

# %%
df_exams.head(3)
# Out:
#          order_id  order_date   status   item_id                  sku  \
# 285229  100562368  2021-09-30      cod  905183.0  SADBWH5B74016CC02D8
# 132953  100562323  2021-09-30  pending  905125.0  APPOSA5ACDCB6C15A68
# 132954  100562323  2021-09-30  pending  905126.0  APPOSA5ACDC3029F2C4
#
#         qty_ordered  price  value  discount_amount  total  ...          SSN  \
# 285229         11.0   30.0  300.0              0.0  300.0  ...  303-37-8555
# 132953          6.0    3.1   15.5              0.0   15.5  ...  727-10-1213
# 132954          6.0    2.8   14.0              0.0   14.0  ...  727-10-1213
#
#           Phone No.  Place Name     County      City State    Zip Region  \
# 285229  304-401-5727    Parsons     Tucker   Parsons    WV  26287  South
# 132953  803-241-8251   Columbia  Lexington  Columbia    SC  29228  South
# 132954  803-241-8251   Columbia  Lexington  Columbia    SC  29228  South
#
#         User Name Discount_Percent
# 285229  pgmccurdy              0.0
# ...
