# %% [markdown]
# # Datra frame manipulation

# %% [markdown]
# here we see diferent way to manipulate dataframes

# %% [markdown]
# # Selecting One Column from a Dataframe

# %%
# import pandas
import pandas as pd
# import numpy
import numpy as np

# %%
# reading the csv file
df_exams = pd.read_csv('hotel_bookings.csv')
df_exams.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %% [markdown]
# # Selecting one column [ ]

# %% [markdown]
# using series in 1d and the size its immutable but the data its mutable

# %% [markdown]
# ### Syntax 1

# %%
# select a column with [] (preferred way to select a column)
df_exams['customer_type']
# Out:
# 0         Transient
# 1         Transient
# 2         Transient
# 3         Transient
# 4         Transient
#             ...
# 119385    Transient
# 119386    Transient
# 119387    Transient
# 119388    Transient
# 119389    Transient
# Name: customer_type, Length: 119390, dtype: object

# %%
# check out the data type of a column
type(df_exams['customer_type'])
# Out:
# pandas.core.series.Series

# %%
# series: attributes and methods
df_exams['customer_type'].index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %%
df_exams['customer_type'].head()
# Out:
# 0    Transient
# 1    Transient
# 2    Transient
# 3    Transient
# 4    Transient
# Name: customer_type, dtype: object

# %% [markdown]
# ### Syntax 2

# %% [markdown]
# this syntax its only valid for one value or a serie

# %%
# select a column with .
df_exams.customer_type
# Out:
# 0         Transient
# 1         Transient
# 2         Transient
# 3         Transient
# 4         Transient
#             ...
# 119385    Transient
# 119386    Transient
# 119387    Transient
# 119388    Transient
# 119389    Transient
# Name: customer_type, Length: 119390, dtype: object

# %% [markdown]
# if there its an space in the title we need to use the other way so we dont get an error

# %%
# select a column with . (pitfalls)
# this will fail if there its a space in the title of the column
df_exams.math score
# Out:
#   File "C:\Users\hanns\AppData\Local\Temp/ipykernel_23720/1791884738.py", line 3
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Selecting Two or More Columns from a Dataframe [[ ]]

# %% [markdown]
# using dataframe in 2d and the size its mutable but the data its mutable also we need to use double [[ ]]

# %%
# select 2 or more columns using [[]]
df_exams[['customer_type', 'deposit_type', 'arrival_date_year']]

# %%
# check out the data type of the selection
type(df_exams[['customer_type', 'deposit_type','arrival_date_year']])

# %%
# we can't select 2 or more columns with the "."
df_exams.'customer_type', 'deposit_type'

# %% [markdown]
# # Add New Column to a Dataframe

# %% [markdown]
# ### Adding a new column with a scalar value

# %% [markdown]
# all the rows have the same value with this form

# %%
# adding new column to dataframe with a unique value

df_exams['language score'] = 70
df_exams
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# 2                    July                        27
# 3                    July                        27
# 4                    July                        27
# ...                   ...                       ...
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  ...  agent  company  \
# 0                          0       2  ...    NaN      NaN
# 1                          0       2  ...    NaN      NaN
# 2                          1       1  ...    NaN      NaN
# 3                          1       1  ...  304.0      NaN
# 4                          2       2  ...  240.0      NaN
# ...                      ...     ...  ...    ...      ...
# 119385                     5       2  ...  394.0      NaN
# 119386                     5       3  ...    9.0      NaN
# 119387                     5       2  ...    9.0      NaN
# 119388                     5       2  ...   89.0      NaN
# 119389                     7       2  ...    9.0      NaN
#
#        days_in_waiting_list customer_type     adr required_car_parking_spaces  \
# 0                         0     Transient    0.00                           0
# 1                         0     Transient    0.00                           0
# 2                         0     Transient   75.00                           0
# 3                         0     Transient   75.00                           0
# 4                         0     Transient   98.00                           0
# ...                     ...           ...     ...                         ...
# 119385                    0     Transient   96.14                           0
# 119386                    0     Transient  225.43                           0
# 119387                    0     Transient  157.71                           0
# 119388                    0     Transient  104.40                           0
# 119389                    0     Transient  151.20                           0
#
#         total_of_special_requests  reservation_status  \
# 0                               0           Check-Out
# 1                               0           Check-Out
# 2                               0           Check-Out
# 3                               0           Check-Out
# 4                               1           Check-Out
# ...                           ...                 ...
# 119385                          0           Check-Out
# 119386                          2           Check-Out
# 119387                          4           Check-Out
# 119388                          0           Check-Out
# 119389                          2           Check-Out
#
#         reservation_status_date language score
# 0                    2015-07-01             70
# 1                    2015-07-01             70
# 2                    2015-07-02             70
# 3                    2015-07-02             70
# 4                    2015-07-03             70
# ...                         ...            ...
# 119385               2017-09-06             70
# 119386               2017-09-07             70
# 119387               2017-09-07             70
# 119388               2017-09-07             70
# 119389               2017-09-07             70
#
# [119390 rows x 33 columns]

# %%
df_exams.shape
# Out:
# (119390, 33)

# %% [markdown]
# ### Adding a new column with an array

# %% [markdown]
# The dataframe has 119390 rows, so we need to create an array with 1000 elements also
# the number of rows have to mach the number of rows

# %%
# create an array of 119390 elements
# we create this array
Language_array = np.arange(0, 119390)

# %%
# length of the array
len(Language_array)
# Out:
# 119390

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = Language_array
df_exams
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# 2                    July                        27
# 3                    July                        27
# 4                    July                        27
# ...                   ...                       ...
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  ...  agent  company  \
# 0                          0       2  ...    NaN      NaN
# 1                          0       2  ...    NaN      NaN
# 2                          1       1  ...    NaN      NaN
# 3                          1       1  ...  304.0      NaN
# 4                          2       2  ...  240.0      NaN
# ...                      ...     ...  ...    ...      ...
# 119385                     5       2  ...  394.0      NaN
# 119386                     5       3  ...    9.0      NaN
# 119387                     5       2  ...    9.0      NaN
# 119388                     5       2  ...   89.0      NaN
# 119389                     7       2  ...    9.0      NaN
#
#        days_in_waiting_list customer_type     adr required_car_parking_spaces  \
# 0                         0     Transient    0.00                           0
# 1                         0     Transient    0.00                           0
# 2                         0     Transient   75.00                           0
# 3                         0     Transient   75.00                           0
# 4                         0     Transient   98.00                           0
# ...                     ...           ...     ...                         ...
# 119385                    0     Transient   96.14                           0
# 119386                    0     Transient  225.43                           0
# 119387                    0     Transient  157.71                           0
# 119388                    0     Transient  104.40                           0
# 119389                    0     Transient  151.20                           0
#
#         total_of_special_requests  reservation_status  \
# 0                               0           Check-Out
# 1                               0           Check-Out
# 2                               0           Check-Out
# 3                               0           Check-Out
# 4                               1           Check-Out
# ...                           ...                 ...
# 119385                          0           Check-Out
# 119386                          2           Check-Out
# 119387                          4           Check-Out
# 119388                          0           Check-Out
# 119389                          2           Check-Out
#
#         reservation_status_date language score
# 0                    2015-07-01              0
# 1                    2015-07-01              1
# 2                    2015-07-02              2
# 3                    2015-07-02              3
# 4                    2015-07-03              4
# ...                         ...            ...
# 119385               2017-09-06         119385
# 119386               2017-09-07         119386
# 119387               2017-09-07         119387
# 119388               2017-09-07         119388
# 119389               2017-09-07         119389
#
# [119390 rows x 33 columns]

# %% [markdown]
# ### creating random reañ numbers with out decimals

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1, 100, size=119390)

# %%
# min value inclusive and high value exclusive
print(min(int_language_score))
print(max(int_language_score))
# Out:
# 1
# 99

# %% [markdown]
# ### change a value of a whole cell

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# 2                    July                        27
# 3                    July                        27
# 4                    July                        27
# ...                   ...                       ...
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  ...  agent  company  \
# 0                          0       2  ...    NaN      NaN
# 1                          0       2  ...    NaN      NaN
# 2                          1       1  ...    NaN      NaN
# 3                          1       1  ...  304.0      NaN
# 4                          2       2  ...  240.0      NaN
# ...                      ...     ...  ...    ...      ...
# 119385                     5       2  ...  394.0      NaN
# 119386                     5       3  ...    9.0      NaN
# 119387                     5       2  ...    9.0      NaN
# 119388                     5       2  ...   89.0      NaN
# 119389                     7       2  ...    9.0      NaN
#
#        days_in_waiting_list customer_type     adr required_car_parking_spaces  \
# 0                         0     Transient    0.00                           0
# 1                         0     Transient    0.00                           0
# 2                         0     Transient   75.00                           0
# 3                         0     Transient   75.00                           0
# 4                         0     Transient   98.00                           0
# ...                     ...           ...     ...                         ...
# 119385                    0     Transient   96.14                           0
# 119386                    0     Transient  225.43                           0
# 119387                    0     Transient  157.71                           0
# 119388                    0     Transient  104.40                           0
# 119389                    0     Transient  151.20                           0
#
#         total_of_special_requests  reservation_status  \
# 0                               0           Check-Out
# 1                               0           Check-Out
# 2                               0           Check-Out
# 3                               0           Check-Out
# 4                               1           Check-Out
# ...                           ...                 ...
# 119385                          0           Check-Out
# 119386                          2           Check-Out
# 119387                          4           Check-Out
# 119388                          0           Check-Out
# 119389                          2           Check-Out
#
#         reservation_status_date language score
# 0                    2015-07-01             87
# 1                    2015-07-01             23
# 2                    2015-07-02             80
# 3                    2015-07-02             41
# 4                    2015-07-03             64
# ...                         ...            ...
# 119385               2017-09-06             18
# 119386               2017-09-07             27
# 119387               2017-09-07             76
# 119388               2017-09-07             92
# 119389               2017-09-07             82
#
# [119390 rows x 33 columns]

# %% [markdown]
# ### creating random float numbers

# %%
# create random float numbers between 1 and 100
np.random.uniform(1, 10, size=10)
# Out:
# array([1.55477645, 7.40127852, 3.58066434, 6.94226836, 4.75235154,
#        8.80778991, 6.17030062, 5.27945863, 2.51880772, 2.2300653 ])
